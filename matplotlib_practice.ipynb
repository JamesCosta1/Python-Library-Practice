# %% [markdown]
# <h1>
# <Center>
#
# Matplotlib Follow Along
#
# </Center>
# </h1>
#
# <h4>
#
# <center>
# This notebook is a follow along to the video: https://www.youtube.com/watch?v=qErBw-R2Ybk&t=884s
# </center>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
year = [2014, 2015, 2016, 2017, 2018]

apl_price = [93.95, 112.15, 104.05, 144.85, 169.49]

ms_price = [39.01, 50.29, 57.05, 69.98, 94.39]

# %%
plt.plot(year, apl_price, '--k',
        year, ms_price, '-.b')

plt.xlabel('Year')
plt.ylabel('Stock Price')

plt.axis([2013, 2019, 20, 180])

plt.show()
